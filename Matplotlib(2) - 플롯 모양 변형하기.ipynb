# %%
# %matplotlib nbagg
from matplotlib import pyplot as plt

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(221)

# %%
ax2 = fig.add_subplot(222)

# %%
ax3 = fig.add_subplot(223)

# %%
import numpy as np
import pandas as pd

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
ax1.hist(np.random.randn(100), bins=20);

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 *np.random.randn(30))

# %%
fig , axes = plt.subplots(2, 3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000297B28DF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000297AD280F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000297AD72160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000297AE7D080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000297AD7BC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000297AF9DE10>]],
#       dtype=object)

# %%
plt.plot(np.random.randn(30), color='g', marker='o', linestyle='--')

# %%
plt.plot(np.random.randn(30), 'k.-')

# %%
fig, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.Series(np.random.rand(16), index = list('abcdefghijklmnop'))

# %%
data.plot(kind='bar', ax = axes[0], color='k', alpha=0.7)

# %%
data.plot(kind='barh', ax=axes[1], color='g', alpha = 0.3)

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(111)

# %%
ax.plot(np.random.randn(1000).cumsum())
# 축의 눈금을 tick이라고 부른다.

# %%
ax.set_xticks([0, 250, 500, 750, 1000])
# Out:
# [<matplotlib.axis.XTick at 0x297ced7dd8>,
#  <matplotlib.axis.XTick at 0x297cef2048>,
#  <matplotlib.axis.XTick at 0x297b1c4978>,
#  <matplotlib.axis.XTick at 0x297ad87390>,
#  <matplotlib.axis.XTick at 0x297b2783c8>]

# %%
labels = ax.set_xticklabels(['one',' two', 'three', 'four', 'five'],
                           rotation = 30, fontsize='small')

# %%
ax.set_title("Random walk plot")
# Out:
# Text(0.5,1,'Random walk plot')

# %%
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
# Out:
# Text(44.4028,0.5,'Values')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(np.random.randn(1000).cumsum(), 'k', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'b--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')

# %%
# loc인자에 best를 주게되면 최적의 위치에 범례를 위치시켜줌.
# 다른 인자도 가능함
ax.legend(loc="best")

# %%
ax.get_xlim()
# Out:
# (-49.95, 1048.95)

# %%
ax.set_xlim([100, 900])
# Out:
# (100, 900)

# %%
ax.set_ylim([-100, 100])
# Out:
# (-100, 100)
