# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(6,4))

# %%
df
# Out:
#           0         1         2         3
# 0 -0.830689  0.850099 -0.635668 -0.786560
# 1  0.167560  1.306938  0.118007  2.579041
# 2 -0.638141 -1.862783 -1.170930  0.202420
# 3 -0.441880  0.094611  1.246931  0.045862
# 4  0.452242 -0.005226 -0.541208  0.470736
# 5  0.269721  0.265055  0.604615  0.665674

# %%
df.columns = ['A', 'B', 'C', 'D']
df.index = pd.date_range("20190217", periods = 6)

# %%
df.index
# Out:
# DatetimeIndex(['2019-02-17', '2019-02-18', '2019-02-19', '2019-02-20',
#                '2019-02-21', '2019-02-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
df
# Out:
#                    A         B         C         D
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560
# 2019-02-18  0.167560  1.306938  0.118007  2.579041
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736
# 2019-02-22  0.269721  0.265055  0.604615  0.665674

# %%
df['F'] = [1.0, np.nan, 3.5, 6.1, np.nan, 7.0]

# %%
df
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
# NaN이 하나라도 포함되어 있으면 삭제하기
df.dropna(how='any')
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
df
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
# 모두 NaN인 경우에만 삭제하기
df.dropna(how='all')
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
# NaN 채우기
df.fillna(value = 5.0)
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  5.0
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  5.0
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
df
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
df.isnull()
# Out:
#                 A      B      C      D      F
# 2019-02-17  False  False  False  False  False
# 2019-02-18  False  False  False  False   True
# 2019-02-19  False  False  False  False  False
# 2019-02-20  False  False  False  False  False
# 2019-02-21  False  False  False  False   True
# 2019-02-22  False  False  False  False  False

# %%
df.loc[df.isnull()['F'], :]
# Out:
#                    A         B         C         D   F
# 2019-02-18  0.167560  1.306938  0.118007  2.579041 NaN
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736 NaN

# %%
df
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
pd.to_datetime("20190217")
# Out:
# Timestamp('2019-02-17 00:00:00')

# %%
# 행 삭제하기
df.drop(pd.to_datetime("20190217"))
# Out:
#                    A         B         C         D    F
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
df.drop([pd.to_datetime("20190218"), pd.to_datetime("20190219")])
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0

# %%
# 열 삭제하기
df.drop('F', axis=1)
# Out:
#                    A         B         C         D
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560
# 2019-02-18  0.167560  1.306938  0.118007  2.579041
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736
# 2019-02-22  0.269721  0.265055  0.604615  0.665674

# %%
df.drop(['B', 'D'], axis=1)
# Out:
#                    A         C    F
# 2019-02-17 -0.830689 -0.635668  1.0
# 2019-02-18  0.167560  0.118007  NaN
# 2019-02-19 -0.638141 -1.170930  3.5
# 2019-02-20 -0.441880  1.246931  6.1
# 2019-02-21  0.452242 -0.541208  NaN
# 2019-02-22  0.269721  0.604615  7.0

# %%
df
# Out:
#                    A         B         C         D    F
# 2019-02-17 -0.830689  0.850099 -0.635668 -0.786560  1.0
# 2019-02-18  0.167560  1.306938  0.118007  2.579041  NaN
# 2019-02-19 -0.638141 -1.862783 -1.170930  0.202420  3.5
# 2019-02-20 -0.441880  0.094611  1.246931  0.045862  6.1
# 2019-02-21  0.452242 -0.005226 -0.541208  0.470736  NaN
# 2019-02-22  0.269721  0.265055  0.604615  0.665674  7.0
